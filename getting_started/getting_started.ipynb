# %% [markdown]
# # Getting Started

# %% [raw]
# .. toctree::
#    :maxdepth: 2
#    :hidden:
#
#    part1
#    part2
#    part3

# %% [markdown]
# This guide covers the steps to get started with **azcausal**.
# We have split this introduction into several parts:

# %% [raw]
# - `Part I <part1.ipynb>`_: **The Panel**
# - `Part II <part2.ipynb>`_: **The Treatment Effect**
# - `Part III <part3.ipynb>`_: **Analysis & Visualization**
